# %% [markdown]
# ##Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Loading dataset

# %%
df=pd.read_csv('house_prices.csv')

# %%
df.head()
# Out:
#    Index                                              Title  \
# 0      0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1      1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2      2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3      3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4      4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description Amount(in rupees)  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...           42 Lac
# 1  One can find this stunning 2 BHK flat for sale...           98 Lac
# 2  Up for immediate sale is a 2 BHK apartment in ...          1.40 Cr
# 3  This beautiful 1 BHK Flat is available for sal...           25 Lac
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...          1.60 Cr
#
#    Price (in rupees) location Carpet Area         Status         Floor  \
# 0             6000.0    thane    500 sqft  Ready to Move  10 out of 11
# 1            13799.0    thane    473 sqft  Ready to Move   3 out of 22
# 2            17500.0    thane    779 sqft  Ready to Move  10 out of 29
# 3                NaN    thane    530 sqft  Ready to Move    1 out of 3
# 4            18824.0    thane    635 sqft  Ready to Move  20 out of 42
#
#   Transaction  ... facing             overlooking  \
# 0      Resale  ...    NaN                     NaN
# 1      Resale  ...   East             Garden/Park
# 2      Resale  ...   East             Garden/Park
# 3      Resale  ...    NaN                     NaN
# 4      Resale  ...   West  Garden/Park, Main Road
#
#                                Society Bathroom Balcony Car Parking  \
# 0  Srushti Siddhi Mangal Murti Complex        1       2         NaN
# 1                          Dosti Vihar        2     NaN      1 Open
# 2                 Sunrise by Kalpataru        2     NaN   1 Covered
# 3                                  NaN        1       1         NaN
# 4          TenX Habitat Raymond Realty        2     NaN   1 Covered
#
#               Ownership Super Area Dimensions  Plot Area
# 0                   NaN        NaN        NaN        NaN
# 1              Freehold        NaN        NaN        NaN
# 2              Freehold        NaN        NaN        NaN
# 3                   NaN        NaN        NaN        NaN
# 4  Co-operative Society        NaN        NaN        NaN
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (83079, 21)

# %% [markdown]
# ##Data Processing

# %%
df.info
# Out:
# <bound method DataFrame.info of        Index                                              Title  \
# 0          0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1          1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2          2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3          3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4          4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
# ...      ...                                                ...
# 83074  83074    1 BHK Ready to Occupy Flat for sale Mohan Nagar
# 83075  83075  3 BHK Ready to Occupy Flat for sale Income Tax...
# 83076  83076  2 BHK Ready to Occupy Flat for sale Siddharth ...
# 83077  83077  2 BHK Ready to Occupy Flat for sale Siddharth ...
# 83078  83078  3 BHK Ready to Occupy Flat for sale Vidyut Nag...
#
#                                              Description Amount(in rupees)  \
# 0      Bhiwandi, Thane has an attractive 1 BHK Flat f...           42 Lac
# 1      One can find this stunning 2 BHK flat for sale...           98 Lac
# 2      Up for immediate sale is a 2 BHK apartment in ...          1.40 Cr
# 3      This beautiful 1 BHK Flat is available for sal...           25 Lac
# 4      This lovely 2 BHK Flat in Pokhran Road, Thane ...          1.60 Cr
# ...                                                  ...               ...
# 83074  One can find this stunning 1 BHK flat for sale...           13 Lac
# 83075  This lovely 3 BHK Flat in Income Tax Colony, J...           45 Lac
# 83076  Discover this immaculate 2 BHK flat for sale a...           40 Lac
# 83077  Discover this immaculate 2 BHK flat for sale a...           38 Lac
# 83078  Up for immediate sale is a 3 BHK apartment in ...          1.25 Cr
#
#        Price (in rupees) location Carpet Area         Status         Floor  \
# 0                 6000.0    thane    500 sqft  Ready to Move  10 out of 11
# 1                13799.0    thane    473 sqft  Ready to Move   3 out of 22
# 2                17500.0    thane    779 sqft  Ready to Move  10 out of 29
# 3                    NaN    thane    530 sqft  Ready to Move    1 out of 3
# 4                18824.0    thane    635 sqft  Ready to Move  20 out of 42
# ...                  ...      ...         ...            ...           ...
# 83074             2364.0   jaipur         NaN  Ready to Move    4 out of 6
# 83075             3513.0   jaipur         NaN  Ready to Move    1 out of 4
# 83076             3478.0   jaipur         NaN  Ready to Move    1 out of 4
# 83077             3455.0   jaipur         NaN  Ready to Move    1 out of 4
# 83078                NaN   jaipur   2000 sqft  Ready to Move    1 out of 6
#
#         Transaction  ... facing             overlooking  \
# 0            Resale  ...    NaN                     NaN
# 1            Resale  ...   East             Garden/Park
# 2            Resale  ...   East             Garden/Park
# 3            Resale  ...    NaN                     NaN
# 4            Resale  ...   West  Garden/Park, Main Road
# ...             ...  ...    ...                     ...
# 83074        Resale  ...    NaN                     NaN
# 83075        Resale  ...    NaN                     NaN
# 83076  New Property  ...   East               Main Road
# 83077  New Property  ...   West               Main Road
# 83078        Resale  ...    NaN                     NaN
#
#                                    Society Bathroom Balcony Car Parking  \
# 0      Srushti Siddhi Mangal Murti Complex        1       2         NaN
# 1                              Dosti Vihar        2     NaN      1 Open
# 2                     Sunrise by Kalpataru        2     NaN   1 Covered
# 3                                      NaN        1       1         NaN
# 4              TenX Habitat Raymond Realty        2     NaN   1 Covered
# ...                                    ...      ...     ...         ...
# 83074                                  NaN        1     NaN         NaN
# 83075                                  NaN        2     NaN         NaN
# 83076                                  NaN        2       2         NaN
# 83077                                  NaN        2       2         NaN
# 83078                                  NaN        3       3         NaN
#
#                   Ownership Super Area Dimensions  Plot Area
# 0                       NaN        NaN        NaN        NaN
# 1                  Freehold        NaN        NaN        NaN
# 2                  Freehold        NaN        NaN        NaN
# 3                       NaN        NaN        NaN        NaN
# 4      Co-operative Society        NaN        NaN        NaN
# ...                     ...        ...        ...        ...
# 83074                   NaN   550 sqft        NaN        NaN
# 83075                   NaN  1281 sqft        NaN        NaN
# 83076              Freehold  1150 sqft        NaN        NaN
# 83077              Freehold  1100 sqft        NaN        NaN
# 83078                   NaN        NaN        NaN        NaN
#
# [83079 rows x 21 columns]>

# %%
df.describe()
# Out:
#               Index  Price (in rupees)  Dimensions  Plot Area
# count  83079.000000       75949.000000         0.0        0.0
# mean   41539.000000        7909.079698         NaN        NaN
# std    23982.985844        4741.423164         NaN        NaN
# min        0.000000          17.000000         NaN        NaN
# 25%    20769.500000        5250.000000         NaN        NaN
# 50%    41539.000000        6522.000000         NaN        NaN
# 75%    62308.500000        9161.000000         NaN        NaN
# max    83078.000000       84619.000000         NaN        NaN

# %%
df = df.drop('Index', axis = 'columns')

# %%
df.rename(columns = { 'Amount(in rupees)': 'Amount_in_rupees',
                     'Price (in rupees)': 'Price_in_repees',
                     'Carpet Area': 'Carpet_area_in_sqft'}, inplace = True)

# %% [markdown]
# ##Check for null values

# %%
null_percent = df.isnull().mean() * 100
null_percent
# Out:
# Title                    0.000000
# Description              1.658662
# Amount_in_rupees         0.000000
# Price_in_repees          8.582193
# location                 0.000000
# Carpet_area_in_sqft     49.905512
# Status                   0.399620
# Floor                    4.754511
# Transaction              0.033703
# Furnishing               2.406144
# facing                  39.538271
# overlooking             48.499621
# Society                 67.494794
# Bathroom                 0.481469
# Balcony                 32.698997
# Car Parking             56.142948
# Ownership               38.737828
# Super Area              50.977985
# Dimensions             100.000000
# Plot Area              100.000000
# dtype: float64

# %%
# Find columns where null percentage is greater than 50
miss_value_50_perc = null_percent[null_percent > 50]

# Drop the columns from the DataFrame
df = df.drop(columns=miss_value_50_perc.index)

# %%
df.shape
# Out:
# (83079, 15)

# %% [markdown]
# ##Convert data from string to float

# %%
## Handling Carpet Area:
def convert_to_sqft(area):
    try:
        if pd.notnull(area):
            if 'sqft' in area:
                area= float(area.replace(' sqft',''))
            else:
                area=float(area.replace(' sqm',''))*10.7639
            return area
    except ValueError:
        return np.nan

df['Carpet_area_in_sqft']=df['Carpet_area_in_sqft'].apply(convert_to_sqft)

# %%
## Handling the amount in rupees

def convert_rupees(amount_str):
    try:
        parts=amount_str.split()
        amount=float(parts[0])

        if len(parts)>1:
            unit=parts[1].strip()
            if unit=='Lac':
                amount*=100000
            elif unit=='Cr':
                amount*=10000000
        return amount
    except(ValueError,IndexError):
        return None

df['Amount_in_rupees']= df['Amount_in_rupees'].apply(convert_rupees)

# %%
df.describe()
# Out:
#        Amount_in_rupees  Price_in_repees  Carpet_area_in_sqft
# count      7.927500e+04     75949.000000         39317.000000
# mean       1.399061e+07      7909.079698          1424.345611
# std        1.572157e+07      4741.423164          1479.182124
# min        2.000000e+05        17.000000            25.000000
# 25%        6.355000e+06      5250.000000           900.000000
# 50%        8.800000e+06      6522.000000          1175.000000
# 75%        1.550000e+07      9161.000000          1700.000000
# max        6.000000e+08     84619.000000        194936.000000

# %% [markdown]
# ##Fill the null values

# %% [markdown]
# ###For Categorical Data

# %%
categorical_features = df.select_dtypes(include = ['object']).columns
categorical_features.tolist()
# Out:
# ['Title',
#  'Description',
#  'location',
#  'Status',
#  'Floor',
#  'Transaction',
#  'Furnishing',
#  'facing',
#  'overlooking',
#  'Bathroom',
#  'Balcony',
#  'Ownership']

# %%
for categorical_feature in categorical_features :
    if df[categorical_feature].isnull().sum() != 0 :
        df[categorical_feature].replace(np.nan, df[categorical_feature].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Title                      0
# Description                0
# Amount_in_rupees        3804
# Price_in_repees         7130
# location                   0
# Carpet_area_in_sqft    43762
# Status                     0
# Floor                      0
# Transaction                0
# Furnishing                 0
# facing                     0
# overlooking                0
# Bathroom                   0
# Balcony                    0
# Ownership                  0
# dtype: int64

# %% [markdown]
# ###For numaric data

# %%
numaric_features = df.select_dtypes(include = ['float64']).columns
numaric_features.tolist()
# Out:
# ['Amount_in_rupees', 'Price_in_repees', 'Carpet_area_in_sqft']

# %%
for numaric_feature in numaric_features :
    if df[numaric_feature].isnull().sum() != 0 :
        df[numaric_feature].replace(np.nan, df[numaric_feature].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Title                  0
# Description            0
# Amount_in_rupees       0
# Price_in_repees        0
# location               0
# Carpet_area_in_sqft    0
# Status                 0
# Floor                  0
# Transaction            0
# Furnishing             0
# facing                 0
# overlooking            0
# Bathroom               0
# Balcony                0
# Ownership              0
# dtype: int64

# %% [markdown]
# ###Analysis

# %%
# Calculate correlation matrix
correlation_matrix = df.select_dtypes(include=['int64', 'float64']).corr()

# Display correlation matrix
print(correlation_matrix)
# Out:
#                      Amount_in_rupees  Price_in_repees  Carpet_area_in_sqft
# Amount_in_rupees             1.000000         0.757756             0.363830
# Price_in_repees              0.757756         1.000000             0.165931
# Carpet_area_in_sqft          0.363830         0.165931             1.000000

# %% [markdown]
# ###Encoding of categorical data

# %%
# Status has only one value for all example that's why remove it.
df.drop(['Status', 'Title', 'Description'], axis = 'columns', inplace = True)

# %%
df.head()
# Out:
#    Amount_in_rupees  Price_in_repees location  Carpet_area_in_sqft  \
# 0         4200000.0      6000.000000    thane                500.0
# 1         9800000.0     13799.000000    thane                473.0
# 2        14000000.0     17500.000000    thane                779.0
# 3         2500000.0      7909.079698    thane                530.0
# 4        16000000.0     18824.000000    thane                635.0
#
#           Floor Transaction      Furnishing facing             overlooking  \
# 0  10 out of 11      Resale     Unfurnished   East             Garden/Park
# 1   3 out of 22      Resale  Semi-Furnished   East             Garden/Park
# 2  10 out of 29      Resale     Unfurnished   East             Garden/Park
# 3    1 out of 3      Resale     Unfurnished   East             Garden/Park
# 4  20 out of 42      Resale     Unfurnished   West  Garden/Park, Main Road
#
#   Bathroom Balcony             Ownership
# 0        1       2              Freehold
# 1        2       2              Freehold
# 2        2       2              Freehold
# 3        1       1              Freehold
# 4        2       2  Co-operative Society

# %%
from sklearn.preprocessing import LabelEncoder

def label_encode_multiple(df, columns):
    encoder = LabelEncoder()
    for column in columns:
        df[column] = encoder.fit_transform(df[column])
    return df

label_encode_columns = ['Transaction','location', 'Furnishing', 'facing', 'overlooking', 'Ownership']
df = label_encode_multiple(df, label_encode_columns)

# %%
df['Floor'].value_counts()
# Out:
# Floor
# 1 out of 4      10283
# 2 out of 4       3959
# 4 out of 4       2907
# 2 out of 5       2765
# 3 out of 4       2710
#                 ...
# 8 out of 26         1
# 30 out of 44        1
# 51 out of 78        1
# 12 out of 52        1
# 32 out of 34        1
# Name: count, Length: 864, dtype: int64

# %%
# Split 'Floor' into two separate columns: current_floor and total_floors
df[['current_floor', 'total_floors']] = df['Floor'].str.split(' out of ', expand=True)

# Display the DataFrame with the new columns
print(df[['Floor', 'current_floor', 'total_floors']])
# Out:
#               Floor current_floor total_floors
# 0      10 out of 11            10           11
# 1       3 out of 22             3           22
# 2      10 out of 29            10           29
# 3        1 out of 3             1            3
# 4      20 out of 42            20           42
# ...             ...           ...          ...
# 83074    4 out of 6             4            6
# 83075    1 out of 4             1            4
# 83076    1 out of 4             1            4
# 83077    1 out of 4             1            4
# 83078    1 out of 6             1            6
#
# [83079 rows x 3 columns]

# %%
encoding_map = {
    'Ground': 0,
    'Upper Basement': -1,
    'Lower Basement': -2,

}

# Apply the encoding to the 'Ownership' column
df['current_floor'] = df['current_floor'].replace(encoding_map)

# %%
df['current_floor'] = df['current_floor'].astype(int)

# %%
df['total_floors'] = df['total_floors'].fillna(df['total_floors'].mode()[0])

# Convert 'total_floors' column to integer data type
df['total_floors'] = df['total_floors'].astype(int)

# %%
df.drop('Floor', axis = 'columns', inplace = True)

# %%
df['Bathroom'] = df['Bathroom'].replace({"> 10" : 11})
df['Bathroom'].value_counts()
# Out:
# Bathroom
# 2     39798
# 3     27591
# 4     10106
# 1      2904
# 5      2528
# 6        96
# 7        18
# 11       16
# 8         9
# 10        8
# 9         5
# Name: count, dtype: int64

# %%
df['Bathroom'] = df['Bathroom'].astype(int)

# %%
df['Balcony'] = df['Balcony'].replace({"> 10" : 11})
df['Balcony'].value_counts()
df['Balcony'] = df['Balcony'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83079 entries, 0 to 83078
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Amount_in_rupees     83079 non-null  float64
#  1   Price_in_repees      83079 non-null  float64
#  2   location             83079 non-null  int64
#  3   Carpet_area_in_sqft  83079 non-null  float64
#  4   Transaction          83079 non-null  int64
#  5   Furnishing           83079 non-null  int64
#  6   facing               83079 non-null  int64
#  7   overlooking          83079 non-null  int64
#  8   Bathroom             83079 non-null  int64
#  9   Balcony              83079 non-null  int64
#  10  Ownership            83079 non-null  int64
#  11  current_floor        83079 non-null  int64
#  12  total_floors         83079 non-null  int64
# dtypes: float64(3), int64(10)
# memory usage: 8.2 MB

# %%
df.head()
# Out:
#    Amount_in_rupees  Price_in_repees  location  Carpet_area_in_sqft  \
# 0         4200000.0      6000.000000        10                500.0
# 1         9800000.0     13799.000000        10                473.0
# 2        14000000.0     17500.000000        10                779.0
# 3         2500000.0      7909.079698        10                530.0
# 4        16000000.0     18824.000000        10                635.0
#
#    Transaction  Furnishing  facing  overlooking  Bathroom  Balcony  Ownership  \
# 0            3           2       0            0         1        2          1
# 1            3           1       0            0         2        2          1
# 2            3           2       0            0         2        2          1
# 3            3           2       0            0         1        1          1
# 4            3           2       7            1         2        2          0
#
#    current_floor  total_floors
# 0             10            11
# 1              3            22
# 2             10            29
# 3              1             3
# 4             20            42

# %% [markdown]
# ###Standardization

# %%
from sklearn.preprocessing import StandardScaler

numeric_df = df[['Price_in_repees', 'Carpet_area_in_sqft']]

scaler = StandardScaler()
numeric_df_standardized = scaler.fit_transform(numeric_df)

df_standardized = pd.DataFrame(numeric_df_standardized, columns=numeric_df.columns)

df_dropped_numeric = df.drop(columns=['Price_in_repees', 'Carpet_area_in_sqft'])
df_combined = pd.concat([df_dropped_numeric, df_standardized], axis=1)

df_combined.head()
# Out:
#    Amount_in_rupees  location  Transaction  Furnishing  facing  overlooking  \
# 0         4200000.0        10            3           2       0            0
# 1         9800000.0        10            3           1       0            0
# 2        14000000.0        10            3           2       0            0
# 3         2500000.0        10            3           2       0            0
# 4        16000000.0        10            3           2       7            1
#
#    Bathroom  Balcony  Ownership  current_floor  total_floors  Price_in_repees  \
# 0         1        2          1             10            11        -0.421117
# 1         2        2          1              3            22         1.299236
# 2         2        2          1             10            29         2.115627
# 3         1        1          1              1             3         0.000000
# 4         2        2          0             20            42         2.407683
#
#    Carpet_area_in_sqft
# 0            -0.908393
# 1            -0.934927
# 2            -0.634208
# 3            -0.878911
# 4            -0.775723

# %%
X = df_combined.drop(columns=['Amount_in_rupees'])
y = df_combined['Amount_in_rupees']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# ##Model Training

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
models = {
    'Random Forest': RandomForestRegressor(random_state=42),
    'Gradient Boosting': GradientBoostingRegressor(random_state=42),
    'XGBRegressor': XGBRegressor(),
}

for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    # Evaluate the model
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    scoree = model.score(X_test,y_test)

    print(f'{model_name}:')
    print(f'R-squared: {r2:.2f}')
    print(f'Mean Absolute Error (MAE): {mae:.2f}')
    print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
    print(f'Accuracy of Model:{scoree:.2f}')
    print('****************************************')
# Out:
# Random Forest:
# R-squared: 0.92
# Mean Absolute Error (MAE): 615549.58
# Root Mean Squared Error (RMSE): 4257168.94
# Accuracy of Model:0.92
# ****************************************
# Gradient Boosting:
# R-squared: 0.92
# Mean Absolute Error (MAE): 1493646.79
# Root Mean Squared Error (RMSE): 4507482.34
# Accuracy of Model:0.92
# ****************************************
# XGBRegressor:
# R-squared: 0.92
# Mean Absolute Error (MAE): 740812.10
# Root Mean Squared Error (RMSE): 4370434.06
# Accuracy of Model:0.92
# ****************************************
